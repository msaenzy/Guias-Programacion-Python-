# %%
print ("ingrese la edad")
edad=int(input())
if edad>=16:
  print ("puede ingresar a ver la pelicula ")
  print ("retire sus gafas 3D ")
else: 
  print (" no tiene la edad requerida")
  print ("no puede entrar a la sala ")

print ("sentencia fuera del bloque if")
print ("las sentencias o lineas de programacion se efectuan en secuencia ")
print ("fin del programa")
# Out:
# ingrese la edad
# 19
# puede ingresar a ver la pelicula
# retire sus gafas 3D
# sentencia fuera del bloque if
# las sentencias o lineas de programacion se efectuan en secuencia
# fin del programa
