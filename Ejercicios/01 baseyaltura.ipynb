# %%
print ("ingrese valor de la base del rectangulo")
base=float(input())
print ("ingrese la altura del rectangulo ")
altura=float(input())
area=base*altura
print ("el valor del area es:", area)
# Out:
# ingrese valor de la base del rectangulo
# 5
# ingrese la altura del rectangulo
# 5
# el valor del area es: 25.0

# %%
#@title Texto de título predeterminado
import math 
print ("ingrese el cateto 1")
cateto1=float(input())
print ("ingrese el cateto 2 ")
cateto2=float(input())
hipotenusa= math.sqrt(math.pow(cateto1, 2)+cateto2**24)
print ("el valor de la hipotenusa es:", hipotenusa)
# Out:
# ingrese el cateto 1
# 3
# ingrese el cateto 2
# 4
# el valor de la hipotenusa es: 5.0

# %%
import math
print ("ingrese el radio del circulo")
r=float(input())
respuesta=(r*r*math.pi)
print ("la superficie del circulo es: ", respuesta)
